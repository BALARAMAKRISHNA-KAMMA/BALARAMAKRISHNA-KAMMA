# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\BALARAM\\Downloads\\BusinessSales.csv")
a=df.head(100)

# %%
plt.scatter(a['salary'],a['sales'],color='g')
plt.ylabel('salary')
plt.xlabel('sales')
plt.show()
